# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

# %% [markdown]
# Dataset 1_______________________________________________________________________________________________

# %%
df = pd.read_csv('../Tarea/autos.csv',encoding='latin-1')
display(df.shape)
df.head()
# Para este dataset lo que busco predecir es la variable de Precio y=price
# Y las variables que considero que pudieran tener alguna relacion para predecir es el x1=model x2=kilometer x3=brand x4=name 
# x1=model  Por que existe diferente tipos de gamas de autos y esto impacta en el precio
# x2=kilometer Esta variable por que esperaria que a mayor kilometraje menor precio debido al deterioro de las piezas
# x3=brand Esta debido a que la diferencia entre las marcas impactan en el precio ejemplo gamas premiun vs gamas comeciales
# x=4 Esta debido a que los modelos de los carros es un diferencuiador tambien del precio
# Out:
# /tmp/ipykernel_6176/1388381392.py:1: DtypeWarning: Columns (0,5,8,10,12,13,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../Tarea/autos.csv',encoding='latin-1')
# (371539, 21)
#   index       dateCrawled                            name  seller offerType  \
# 0     0  24/03/2016 11:52                      Golf_3_1.6  privat   Angebot
# 1     1  24/03/2016 10:58            A5_Sportback_2.7_Tdi  privat   Angebot
# 2     2  14/03/2016 12:52  Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 3     3  17/03/2016 16:54             GOLF_4_1_4__3TÃRER  privat   Angebot
# 4     4  31/03/2016 17:25  Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
#
#    price abtest vehicleType yearOfRegistration    gearbox  ...  model  \
# 0    480   test         NaN               1993    manuell  ...   golf
# 1  18300   test       coupe               2011    manuell  ...    NaN
# 2   9800   test         suv               2004  automatik  ...  grand
# ...

# %% [markdown]
# Dataset 2_______________________________________________________________________________________________

# %%
df1 = pd.read_csv('../Tarea/Ventas SuperStore.csv',encoding='latin-1')
display(df1.shape)
df1.head()
#Quisiera predecir las ganacias que se tendran en 2015 , Y=profit
#Las vairables que considero importante serian x1=sales , x2=quatity , x3=country 
# x1=sales Por que esta variable determina la cantidad vendida
# x2=quantity esta muestra las cantidades
# x3=country y esta el paise , considero importante por que cada pais tiene su propio crecieminto y ventas
# Out:
# (51290, 21)
#           order_id  order_date   ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040  01/01/2011  06/01/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883  01/01/2011  08/01/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220  01/01/2011  05/01/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632  01/01/2011  05/01/2011    Second Class     Eugene Moren
# 4    IN-2011-47883  01/01/2011  08/01/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %% [markdown]
# Dataset 3_______________________________________________________________________________________________

# %%
df2 = pd.read_csv('../Tarea/Amazon Sale Report.csv',encoding='latin-1')
display(df2.shape)
df2.head()
#Quisiera predecir la cantidad de ventas en cantidades  , Y=Qty
#Las vairables que considero importante serian x1=ship-city , x2=Category , x3=Sales Channel 
# x1=ship-city La ciudad por que hay ciudades con diferente cantidad de personas y esto afecta a la cantidad de productos
# x2=Category La categorioa por que cada categoria tiene mercados diferentes y por ende comportamiento diferente
# x3=Sales Channel El canal por que dependiendo del canal es como se comporta el mercado
# Out:
# /tmp/ipykernel_6176/77119180.py:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('../Tarea/Amazon Sale Report.csv',encoding='latin-1')
# (128975, 24)
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# ...
