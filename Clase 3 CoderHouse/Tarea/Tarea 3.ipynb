# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import matplotlib as mpl
import seaborn as sns

# %% [markdown]
# ## Dataset_______________________________________________________________________________________________

# %%
df1 = pd.read_csv('../Tarea/Ventas SuperStore.csv',encoding='latin-1')

#Quisiera predecir las ganacias que se tendran en 2015 , Y=profit
#Las vairables que considero importante serian x1=sales , x2=quatity , x3=country 
# x1=sales Por que esta variable determina la cantidad vendida
# x2=quantity esta muestra las cantidades
# x3=country y esta el paise , considero importante por que cada pais tiene su propio crecieminto y ventas 
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import matplotlib as mpl
import seaborn as sns

# %% [markdown]
# # Vamos a Trabajar con el dataset numero 1 los ejersicion

# %%
display(df1.shape)
display(df1.head(2))
display(df1.info())
display(df1.describe())
# Out:
# (51290, 21)
#         order_id  order_date   ship_date       ship_mode    customer_name  \
# 0   AG-2011-2040  01/01/2011  06/01/2011  Standard Class  Toby Braunhardt
# 1  IN-2011-47883  01/01/2011  08/01/2011  Standard Class      Joseph Holt
#
#     segment            state    country  market   region  ...  \
# 0  Consumer      Constantine    Algeria  Africa   Africa  ...
# 1  Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category              product_name sales quantity  \
# 0  Office Supplies      Storage       Tenex Lockers, Blue   408        2
# 1  Office Supplies     Supplies  Acme Trimmer, High Speed   120        3
#
#    discount   profit  shipping_cost  order_priority  year
# 0       0.0  106.140          35.46          Medium  2011
# 1       0.1   36.036           9.72          Medium  2011
#
# [2 rows x 21 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
# ...

# %% [markdown]
# ## Remplazar Valores Faltantes

# %%
print(df1.isnull().sum()) ## Ver la cantidad de valores nulos
# Out:
# order_id          0
# order_date        0
# ship_date         0
# ship_mode         0
# customer_name     0
# segment           0
# state             0
# country           0
# market            0
# region            0
# product_id        0
# category          0
# sub_category      0
# product_name      0
# sales             0
# quantity          0
# discount          0
# profit            0
# shipping_cost     0
# order_priority    0
# year              0
# dtype: int64

# %% [markdown]
# ## Ver como se ve ahora el Dataframe

# %%
#!pip install missingno
import missingno as msno
# %matplotlib inline
msno.matrix(df1)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Tarea 2 Graficos con Matplotlib y Seaborn , Trabajaremos con el Dataframe 2

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Grafricos en sns

# %%
hisplot = sns.histplot( data=df1, x="discount",hue="ship_mode")
print(hisplot)
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
boxplot = sns.boxplot( data=df1, x="discount",y="ship_mode", palette="vlag")
print(boxplot)
#sns.boxplot?
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
graficojoin = sns.jointplot(data=df1,x="discount",y="category")

# %%
sns.kdeplot(data=df1,x="quantity",hue="ship_mode")
# Out:
# <AxesSubplot: xlabel='quantity', ylabel='Density'>
# Bad pipe message: %s [b"\x9e\xa7\xefp\xe3\xf3Z\xcc,i\xe0-\xa2^p\x13\xc1\x7f\x00\x00|\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0/\x00\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\\xc0`\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0#\xc0'\x00g\x00@\xc0\n\xc0\x14\x009\x008\xc0\t\xc0\x13\x003\x002\x00\x9d\xc0\xa1\xc0"]
# Bad pipe message: %s [b'\xe2Vq\xe4\x15\x160U|\x98S\x893\x93$\xe3\x146\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x004\x00\x9b\x00F\xc0\x0e\xc0\x04\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00\x10\x00\r\xc0\x17\x00\x1b\xc0\r\xc0\x03\x00\n\x00']
# ...

# %% [markdown]
# ## Graficos en plt

# %%
fig, ax = plt.subplots(figsize=(12, 4))
#ax.plot(df1['discount'], df1['quantity'], label='Precipitaciones acumuladas')

mapeo_colores = ax.scatter(df1['discount'], df1['ship_mode'])

#graficojoin = sns.jointplot(data=df1,x="discount",y="category")

# %%
fig, ax = plt.subplots(figsize=(12, 4))

grafica = ax.bar(df1['ship_mode'],df1['discount'])

# %%
plt.violinplot(df1['discount'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x7f9b43ea6530>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7f9b43ea64d0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x7f9b43ea6b00>,
#  'cbars': <matplotlib.collections.LineCollection at 0x7f9b43ea6e60>}

# %%
#fig,ax= plt.subplots(figsize=(10,6))
#ax.plot(df1['discount'], df1['year'], linewidth=1)


plt.boxplot(df1['discount'],notch=True,showmeans=True)
plt.show()
#plt.boxplot?

# %% [markdown]
# ## Tarea 3 _______________________________________________

# %% [markdown]
#  Primeramente mi variable a la cual quiero predecir es el Y=profit , de la cual considero que las variables que tiene una mayor correlacion para poder predecir este valor es el x1=order_priority x2=country
# Quisiera predecir las ganacias que se tendran en 2015 , Y=profit
# Las vairables que considero importante serian x1=sales , x2=quatity , x3=country
#  x1=sales Por que esta variable determina la cantidad vendida
#  x2=quantity esta muestra las cantidades
#  x3=country y esta el paise , considero importante por que cada pais tiene su propio crecieminto y ventas
#
#  De acuerdo a mi hipotesis considero que la variable que tiene que estar muy relacionada con las ganacias es la cantidad , empezare y ver la interacion de esta variable vs el resto de las variables

# %% [markdown]
# #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51290 non-null  object
#  1   order_date      51290 non-null  object
#  2   ship_date       51290 non-null  object
#  3   ship_mode       51290 non-null  object
#  4   customer_name   51290 non-null  object
#  5   segment         51290 non-null  object
#  6   state           51290 non-null  object
#  7   country         51290 non-null  object
#  8   market          51290 non-null  object
#  9   region          51290 non-null  object
#  10  product_id      51290 non-null  object
#  11  category        51290 non-null  object
#  12  sub_category    51290 non-null  object
#  13  product_name    51290 non-null  object
#  14  sales           51290 non-null  object
#  15  quantity        51290 non-null  int64
#  16  discount        51290 non-null  float64
#  17  profit          51290 non-null  float64
#  18  shipping_cost   51290 non-null  float64
#  19  order_priority  51290 non-null  object
#  20  year            51290 non-null  int64
# dtypes: float64(3), int64(2), object(16)

# %%
plt.figure(figsize=(12,6))
sns.violinplot(y='profit',data = df1)
# Out:
# <AxesSubplot: ylabel='profit'>

# %%
plt.scatter(df1['profit'],df1['year'])

# %%
sns.jointplot(x="year", y="profit", data=df1 , kind="reg", truncate=False )

# %%
sns.jointplot(x="quantity", y="profit", data=df1 , kind="reg", truncate=False ,color="m" )

# %% [markdown]
# Aqui vemos que la mayor cantidad de ordenes se encuentran con cantidades bajas

# %%
plt.figure(figsize=(6,3))
sns.histplot(y='profit',data = df1)
# Out:
# <AxesSubplot: xlabel='Count', ylabel='profit'>

# %% [markdown]
# Aqui vemos que la mayoria de ordenes la ganacia es muy pequeña

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='year', y = 'quantity', hue = 'order_priority',data = df1)
# Out:
# <AxesSubplot: xlabel='year', ylabel='quantity'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='order_priority', y = 'quantity',data = df1)
# Out:
# <AxesSubplot: xlabel='order_priority', ylabel='quantity'>

# %% [markdown]
#  En este grafico poder ver como las ordenes con prioridad Critica son las que en la parte del Quartil 4 tiene menor dispersion pero en terminos de mediana no vemos una diferencia significativa

# %%
plt.figure(figsize=(12,6))
sns.boxplot(y = 'quantity',x= 'market',data = df1)
# Out:
# <AxesSubplot: xlabel='market', ylabel='quantity'>

# %% [markdown]
# En este grafico podemos ver como a nivel cantidad Africa EMEA y Canada son los paises que que poder orden compran menos que el resto de paises

# %% [markdown]
# Ahora vamosa revisar las interaciones para ver si efectivamente tienen algun tipo de correlacion

# %%
import statsmodels.formula.api as sm
#import chart_studio.plotly     as py
#pip install plotly

# %%
print(df1.columns)
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
model1 = 'profit~quantity  + ship_mode + order_priority + discount + segment '
lm1   = sm.ols(formula = model1, data = df1).fit()
print(lm1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 profit   R-squared:                       0.110
# Model:                            OLS   Adj. R-squared:                  0.110
# Method:                 Least Squares   F-statistic:                     633.0
# Date:                Wed, 08 Feb 2023   Prob (F-statistic):               0.00
# Time:                        20:54:12   Log-Likelihood:            -3.3452e+05
# No. Observations:               51290   AIC:                         6.691e+05
# Df Residuals:                   51279   BIC:                         6.692e+05
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                      41.9029      3.267     12.827      0.000      35.500      48.306
# ...

# %% [markdown]
# Revisando los resultados vemos que la cantidad y descuento son variables que aparecen siginificativas pero el aporte al modelo es muy pequeño

# %%
model1 = 'profit~discount + year'
lm1   = sm.ols(formula = model1, data = df1).fit()
print(lm1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 profit   R-squared:                       0.100
# Model:                            OLS   Adj. R-squared:                  0.100
# Method:                 Least Squares   F-statistic:                     2852.
# Date:                Wed, 08 Feb 2023   Prob (F-statistic):               0.00
# Time:                        20:54:20   Log-Likelihood:            -3.3481e+05
# No. Observations:               51290   AIC:                         6.696e+05
# Df Residuals:                   51287   BIC:                         6.696e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -188.5408   1338.244     -0.141      0.888   -2811.513    2434.431
# ...

# %% [markdown]
# La conclucion es que como tal este modelo no es el indicado para predecir puesto que las variables que tenemos tienen muy poco aporte y eso lo podemos ver en el R2 que tiene un score de
#  0.11 y para poder considerar un score bueno debe estar arriba de los 0.70
